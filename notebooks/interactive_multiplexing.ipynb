# %% [markdown]
# # Interactive Multiplexing Explorer
#
# This notebook provides a small UI for exploring multiplexing layers, fields, and colorbar styles from the public supplementary-material dataset.

# %%
from pathlib import Path
import sys

repo_root = Path.cwd().resolve().parent
sys.path.insert(0, str(repo_root / "src"))

# %%
from multiplexing import create_interactive_multiplexing_ui

# %%
ui = create_interactive_multiplexing_ui(repo_root)
ui
